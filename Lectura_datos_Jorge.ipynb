# %% [markdown]
# # Comprensión de los Datos

# %%
"""
Jorge Eduardo García Pereda

A01230894

ITC
"""
# Out:
# '\nJorge Eduardo García Pereda\n\nA01230894\n\nITC\n'

# %%
#importa librerías
import pandas as pd

# %% [markdown]
# # Descripción de Variables

# %% [markdown]
# Pclass Passenger Class (1 = 1st; 2 = 2nd; 3 = 3rd): Categórica Nominal
# survival Survival (0 = No; 1 = Yes)
# name Name
# sex Sex
# age Age
# sibsp Number of Siblings/Spouses Aboard
# parch Number of Parents/Children Aboard
# ticket Ticket Number
# fare Passenger Fare (British pound)
# cabin Cabin
# embarked Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)
# boat Lifeboat
# body Body Identification Number
# home.dest Home/Destination

# %% [markdown]
# **Ejemplo:** Crear un objeto DataFrame con base en un archivo .csv

# %%
#lee archivo csv
df = pd.read_csv('diabetes.csv')
diabetes = pd.read_csv("diabetes.csv")

# %%
#Usa función shape para revisar el total de renglones y columnas
df.shape
# Out:
# (768, 9)

# %%
#Revisa los primeros 5 renglones del dataset usando la función head()
df.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#Revisa los últimos 5 renglones del dataset usando la función tail()
df.tail(5)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
#Revisa la información mas completa del conjunto de datos usando la función info()
#Muestra el total de datos, las columnas y su tipo correspondiente, dice si contiene nulos o no
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
#revisa cuántos valores únicos tiene cada atributo del archivo usando la función nunique()
df.nunique()
# Out:
# Pregnancies                  17
# Glucose                     136
# BloodPressure                47
# SkinThickness                51
# Insulin                     186
# BMI                         248
# DiabetesPedigreeFunction    517
# Age                          52
# Outcome                       2
# dtype: int64

# %% [markdown]
# ## Exploración de Datos

# %%
#utiliza la función describe() para obtener estadística básica. se puede incluir -0
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
#Revisa Valores nulos con funcion isnull().sum()
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#Revisar valores únicos por columna usando función unique(): nombre-columna.unique()
df.Pregnancies.unique(), df.Glucose.unique()
# Out:
# (array([ 6,  1,  8,  0,  5,  3, 10,  2,  4,  7,  9, 11, 13, 15, 17, 12, 14]),
#  array([148,  85, 183,  89, 137, 116,  78, 115, 197, 125, 110, 168, 139,
#         189, 166, 100, 118, 107, 103, 126,  99, 196, 119, 143, 147,  97,
#         145, 117, 109, 158,  88,  92, 122, 138, 102,  90, 111, 180, 133,
#         106, 171, 159, 146,  71, 105, 101, 176, 150,  73, 187,  84,  44,
#         141, 114,  95, 129,  79,   0,  62, 131, 112, 113,  74,  83, 136,
#          80, 123,  81, 134, 142, 144,  93, 163, 151,  96, 155,  76, 160,
#         124, 162, 132, 120, 173, 170, 128, 108, 154,  57, 156, 153, 188,
#         152, 104,  87,  75, 179, 130, 194, 181, 135, 184, 140, 177, 164,
#          91, 165,  86, 193, 191, 161, 167,  77, 182, 157, 178,  61,  98,
#         127,  82,  72, 172,  94, 175, 195,  68, 186, 198, 121,  67, 174,
#         199,  56, 169, 149,  65, 190]))

# %% [markdown]
# ## Variables Cuantitativas
#
# ### Medidas de tendencia central

# %%
variables = ["Pregnancies", "Glucose", "Outcome"]
stats = diabetes[variables].describe().T
print(stats)
# Out:
#              count        mean        std  min   25%    50%     75%    max
# Pregnancies  768.0    3.845052   3.369578  0.0   1.0    3.0    6.00   17.0
# Glucose      768.0  120.894531  31.972618  0.0  99.0  117.0  140.25  199.0
# Outcome      768.0    0.348958   0.476951  0.0   0.0    0.0    1.00    1.0

# %%
# Pregnancies
mean_preg = diabetes['Pregnancies'].mean()
median_preg = diabetes['Pregnancies'].median()
mode_preg = diabetes['Pregnancies'].mode()[0]

# Glucose
mean_gluc = diabetes['Glucose'].mean()
median_gluc = diabetes['Glucose'].median()
mode_gluc = diabetes['Glucose'].mode()[0]

# Outcome (proporción)
mean_out = diabetes['Outcome'].mean()

print("Media embarazos:", mean_preg)
print("Mediana embarazos:", median_preg)
print("Moda embarazos:", mode_preg)
print("\nMedia glucosa:", mean_gluc)
print("Mediana glucosa:", median_gluc)
print("Moda glucosa:", mode_gluc)
print("\nProporción de diabéticas:", mean_out)
# Out:
# Media embarazos: 3.8450520833333335
# Mediana embarazos: 3.0
# Moda embarazos: 1
#
# Media glucosa: 120.89453125
# Mediana glucosa: 117.0
# Moda glucosa: 99
#
# Proporción de diabéticas: 0.3489583333333333

# %%
print("""Conclusión:

La media de embarazos es aproximadamente 3.85, la mediana es 3 y la moda es 0.
La media de glucosa es aproximadamente 120.89 mg/dL, la mediana es 117 y la moda es 0.
La media de la variable Outcome es 0.34
""")
# Out:
# Conclusión:
#
# La media de embarazos es aproximadamente 3.85, la mediana es 3 y la moda es 0.
# La media de glucosa es aproximadamente 120.89 mg/dL, la mediana es 117 y la moda es 0.
# La media de la variable Outcome es 0.34

# %%
diabetes[diabetes['Glucose'] > 140].head(),
# Out:
# (    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
#  0             6      148             72             35        0  33.6
#  2             8      183             64              0        0  23.3
#  8             2      197             70             45      543  30.5
#  11           10      168             74              0        0  38.0
#  13            1      189             60             23      846  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
#  0                      0.627   50        1
#  2                      0.672   32        1
#  8                      0.158   53        1
#  11                     0.537   34        1
#  13                     0.398   59        1  ,)

# %%
diabetes[(diabetes['Outcome'] == 1) & (diabetes['Pregnancies'] > 3)].head()
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35        0  33.6
# 2             8      183             64              0        0  23.3
# 9             8      125             96              0        0   0.0
# 11           10      168             74              0        0  38.0
# 14            5      166             72             19      175  25.8
#
#     DiabetesPedigreeFunction  Age  Outcome
# 0                      0.627   50        1
# 2                      0.672   32        1
# 9                      0.232   54        1
# 11                     0.537   34        1
# 14                     0.587   51        1

# %%
diabetes.groupby('Outcome')['Glucose'].mean()
# Out:
# Outcome
# 0    109.980000
# 1    141.257463
# Name: Glucose, dtype: float64

# %% [markdown]
# Visualización y Análisis de Datos

# %%
import matplotlib.pyplot as plt

plt.hist(diabetes['Pregnancies'], bins=10)
plt.title("Histograma de Embarazos")
plt.xlabel("Número de embarazos")
plt.ylabel("Frecuencia")
plt.show()
print ("La mayoría de las pacientes tiene entre 0 y 5 embarazos, con pocos casos elevados.")
# Out:
# La mayoría de las pacientes tiene entre 0 y 5 embarazos, con pocos casos elevados.

# %%
plt.hist(diabetes['Glucose'], bins=15)
plt.title("Histograma de Nivel de Glucosa")
plt.xlabel("Glucosa (mg/dL)")
plt.ylabel("Frecuencia")
plt.show()
print ("Los niveles de glucosa se concentran entre 100 y 150 mg/dL, con algunos valores fuera del rango típico.")
# Out:
# Los niveles de glucosa se concentran entre 100 y 150 mg/dL, con algunos valores fuera del rango típico.

# %%
plt.figure(figsize=(6,5))
sns.boxplot(x=diabetes['Outcome'], y=diabetes['Pregnancies'])
plt.title("Embarazos vs Outcome")
plt.xlabel("Outcome (0 = No diabética, 1 = Diabética)")
plt.ylabel("Número de embarazos")
plt.show()
print ("Las personas con diabetes tienden a tener más embarazos que quienes no presentan la enfermedad")
# Out:
# Las personas con diabetes tienden a tener más embarazos que quienes no presentan la enfermedad

# %%
plt.figure(figsize=(6,5))
sns.boxplot(x=diabetes['Outcome'], y=diabetes['Glucose'])
plt.title("Glucosa vs Outcome")
plt.xlabel("Outcome (0 = No diabética, 1 = Diabética)")
plt.ylabel("Niveles de glucosa")
plt.show()
print ("Las personas con altos números de glucosa en sangre tienden a tener diabetes respecto a quienes tienen un nivel más bajo")
# Out:
# Las personas con altos números de glucosa en sangre tienden a tener diabetes respecto a quienes tienen un nivel más bajo

# %%
import seaborn as sns

plt.figure(figsize=(6,5))
sns.boxplot(data=diabetes[['Pregnancies', 'Glucose']])
plt.title("Boxplots de Pregnancies y Glucose")
plt.ylabel("Valores")
plt.show()

print ("Los embarazos y los niveles de glucosa muestran una gran variación, con valores extremos en ambos casos; la glucosa presenta mayor dispersión general.")
# Out:
# Los embarazos y los niveles de glucosa muestran una gran variación, con valores extremos en ambos casos; la glucosa presenta mayor dispersión general.

# %%
diabetes['Outcome'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Proporción de Outcome (Diabetes)")
plt.ylabel("")
plt.show()
print ("La mayoría de las personas del conjunto de datos no presenta diabetes, mientras que un porcentaje menor corresponde a casos positivos.")
# Out:
# La mayoría de las personas del conjunto de datos no presenta diabetes, mientras que un porcentaje menor corresponde a casos positivos.

# %%
diabetes['Outcome'].value_counts().plot(kind='bar')
plt.title("Conteo de Outcome (0 = No diabética, 1 = Diabética)")
plt.xlabel("Outcome")
plt.ylabel("Frecuencia")
plt.show()
print ("La mayoría de las personas del dataset no presenta diabetes, mientras que una menor proporción resulta diagnosticada.")
# Out:
# La mayoría de las personas del dataset no presenta diabetes, mientras que una menor proporción resulta diagnosticada.

# %%
plt.scatter(diabetes['Pregnancies'], diabetes['Glucose'])
plt.title("Relación entre Embarazos y Glucosa")
plt.xlabel("Número de embarazos")
plt.ylabel("Glucosa (mg/dL)")
plt.show()
print ("No se observa una relación fuerte entre el número de embarazos y los niveles de glucosa; los valores están dispersos sin una tendencia clara.")
# Out:
# No se observa una relación fuerte entre el número de embarazos y los niveles de glucosa; los valores están dispersos sin una tendencia clara.

# %%
colors = diabetes['Outcome'].map({0:'blue', 1:'red'})

plt.scatter(diabetes['Pregnancies'], diabetes['Glucose'], c=colors)
plt.title("Glucosa vs Embarazos (coloreado por Outcome)")
plt.xlabel("Número de embarazos")
plt.ylabel("Glucosa (mg/dL)")
plt.show()
print ("Los niveles de glucosa varían ampliamente en todos los rangos de embarazos, sin una relación marcada entre ambas variables.")
# Out:
# Los niveles de glucosa varían ampliamente en todos los rangos de embarazos, sin una relación marcada entre ambas variables.

# %%
sorted_glucose = diabetes['Glucose'].sort_values().reset_index(drop=True)
plt.plot(sorted_glucose)
plt.title("Tendencia de Glucosa Ordenada")
plt.xlabel("Índice ordenado")
plt.ylabel("Glucosa (mg/dL)")
plt.show()
print ("La glucosa aumenta gradualmente con algunos valores muy altos, mostrando una distribución creciente y presencia de casos extremos.")
# Out:
# La glucosa aumenta gradualmente con algunos valores muy altos, mostrando una distribución creciente y presencia de casos extremos.

# %%
import seaborn as sns

# Matriz de correlación
corr = diabetes.corr()

plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap="coolwarm", linewidths=.5)
plt.title("Mapa de Calor de Correlación")
plt.show()
print ("La glucosa muestra la correlación más alta con el diagnóstico de diabetes, mientras que el número de embarazos tiene una relación moderada.")
# Out:
# La glucosa muestra la correlación más alta con el diagnóstico de diabetes, mientras que el número de embarazos tiene una relación moderada.

# %% [markdown]
# # Variables Categóricas

# %%
#Para conteo  de cada valor en una columna, en orden descendente usar función value_counts():    
# nombreDataframe.columna.value_counts()
# nombreDataframe['columna'].value_counts()
df.Pregnancies.value_counts(), df.Glucose.value_counts()
# Out:
# (Pregnancies
#  1     135
#  0     111
#  2     103
#  3      75
#  4      68
#  5      57
#  6      50
#  7      45
#  8      38
#  9      28
#  10     24
#  11     11
#  13     10
#  12      9
#  14      2
#  17      1
#  15      1
#  Name: count, dtype: int64,
#  Glucose
#  99     17
#  100    17
#  111    14
#  125    14
#  129    14
#         ..
#  56      1
#  169     1
#  149     1
#  65      1
#  190     1
#  Name: count, Length: 136, dtype: int64)

# %%
#Revisa conteo de varias columnas
df[['Pregnancies', 'Glucose']].value_counts()
# Out:
# Pregnancies  Glucose
# 0            102        5
# 2            112        5
#              100        5
# 1            97         5
# 2            108        5
#                        ..
# 13           152        1
#              153        1
#              158        1
# 14           100        1
#              175        1
# Name: count, Length: 536, dtype: int64

# %%
# Crear variable familySize que incluya la suma de las columnas SibSp y Parch
df['Relación Embarazo-Glucosa'] = df['Pregnancies'] + df['Glucose'] + 1

# Mostrar el total por cada tamaño de familia
df['Relación Embarazo-Glucosa'].value_counts()
# Out:
# Relación Embarazo-Glucosa
# 115    20
# 132    18
# 103    17
# 102    15
# 130    14
#        ..
# 193     1
# 199     1
# 68      1
# 59      1
# 170     1
# Name: count, Length: 140, dtype: int64

# %% [markdown]
# ## Consulta

# %%
# df.iloc[i]: Accede a la fila en la posición i.
# Acceder a la primera fila
df.iloc[0]
# Out:
# Pregnancies                    6.000
# Glucose                      148.000
# BloodPressure                 72.000
# SkinThickness                 35.000
# Insulin                        0.000
# BMI                           33.600
# DiabetesPedigreeFunction       0.627
# Age                           50.000
# Outcome                        1.000
# Relación Embarazo-Glucosa    155.000
# Name: 0, dtype: float64

# %%
# Acceder a las dos primeras filas
df.iloc[[0,1]]
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
#
#    DiabetesPedigreeFunction  Age  Outcome  Relación Embarazo-Glucosa
# 0                     0.627   50        1                        155
# 1                     0.351   31        0                         87

# %%
#Seleccionar columnas, indicando entre corchetes [nombreColumna, nombreColumna]
df[['Pregnancies', 'Glucose']]
# Out:
#      Pregnancies  Glucose
# 0              6      148
# 1              1       85
# 2              8      183
# 3              1       89
# 4              0      137
# ..           ...      ...
# 763           10      101
# 764            2      122
# 765            5      121
# 766            1      126
# 767            1       93
#
# [768 rows x 2 columns]

# %%
#Selección de filas [indicar dataframe[columna] operador valor]
df[df['Pregnancies'] == 1].head()
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1             1       85             66             29        0  26.6
# 3             1       89             66             23       94  28.1
# 13            1      189             60             23      846  30.1
# 18            1      103             30             38       83  43.3
# 19            1      115             70             30       96  34.6
#
#     DiabetesPedigreeFunction  Age  Outcome  Relación Embarazo-Glucosa
# 1                      0.351   31        0                         87
# 3                      0.167   21        0                         91
# 13                     0.398   59        1                        191
# 18                     0.183   33        0                        105
# 19                     0.529   32        1                        117

# %%
#ordenar usando funcion sort_values(by=atributo, ascending=True/false)
df.sort_values(by='Pregnancies', ascending=True).head(), df.sort_values(by='Glucose', ascending=False).head()
# Out:
# (     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
#  16             0      118             84             47      230  45.8
#  736            0      126             86             27      120  27.4
#  713            0      134             58             20      291  26.4
#  727            0      141             84             26        0  32.4
#  681            0      162             76             36        0  49.6
#
#       DiabetesPedigreeFunction  Age  Outcome  Relación Embarazo-Glucosa
#  16                      0.551   31        1                        119
#  736                     0.515   21        0                        127
#  713                     0.352   21        0                        135
#  727                     0.433   22        0                        142
#  681                     0.364   26        1                        163  ,
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# ...

# %%
#Agrupar por un atributo y calcular función de agregación utilizando groupby(atributo)['atributoAgregacion].funcion() (ej. mean() para promedio)
df.groupby('Pregnancies')['Glucose'].mean()
# Out:
# Pregnancies
# 0     123.000000
# 1     112.748148
# 2     110.796117
# 3     123.586667
# 4     125.117647
# 5     118.859649
# 6     120.800000
# 7     136.444444
# 8     131.736842
# 9     131.392857
# 10    120.916667
# 11    126.454545
# 12    113.555556
# 13    125.500000
# 14    137.500000
# 15    136.000000
# 17    163.000000
# Name: Glucose, dtype: float64

# %% [markdown]
# Crea un subconjunto de **titanic** para el costo mayor a 500

# %%
# Glucosa arriba de 100
df_boletos_caros = df[df['Glucose'] > 100]
df_boletos_caros.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 2            8      183             64              0        0  23.3
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 7           10      115              0              0        0  35.3
#
#    DiabetesPedigreeFunction  Age  Outcome  Relación Embarazo-Glucosa
# 0                     0.627   50        1                        155
# 2                     0.672   32        1                        192
# 4                     2.288   33        1                        138
# 5                     0.201   30        0                        122
# 7                     0.134   29        0                        126
